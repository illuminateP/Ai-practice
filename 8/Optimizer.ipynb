# %%
import numpy as np
import tensorflow as tf

a = 0.1
# 기울기 변화
gradient = np.arange(-1, 0, 0.1)

print("학습율 : ", a)
print("기울기 : ", gradient)
# Out:
# 학습율 :  0.1
# 기울기 :  [-1.  -0.9 -0.8 -0.7 -0.6 -0.5 -0.4 -0.3 -0.2 -0.1]

# %%
h = 0
for i in range(len(gradient)) :
    h = h + (gradient[i])
    sqrth = h**1/2
    lr = a * 1/sqrth
    print("** 학습률 : ", lr)
# Out:
# ** 학습률 :  -0.2
# ** 학습률 :  -0.10526315789473685
# ** 학습률 :  -0.07407407407407407
# ** 학습률 :  -0.058823529411764705
# ** 학습률 :  -0.05
# ** 학습률 :  -0.044444444444444446
# ** 학습률 :  -0.04081632653061224
# ** 학습률 :  -0.038461538461538464
# ** 학습률 :  -0.037037037037037035
# ** 학습률 :  -0.03636363636363636
