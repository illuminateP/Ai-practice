# %%
from keras.models import Sequential            # 케라스의 Sequential()을 임포트
from keras.layers import Dense                 # 케라스의 Dense()를 임포트
from keras import optimizers                   # 케라스의 옵티마이저(학습 방법)를 임포트
import numpy as np                             # Numpy를 임포트

# %%
# 1. 데이터
x = np.array([1, 2, 3])             # 공부하는 시간(입력데이터)
y = np.array([1, 2, 3])   # 각 공부하는 시간에 맵핑되는 성적(라벨 / 실제값)

# %%
# 2. 모델 구성
model=Sequential()                                       # 입력층, 중간층, 출력층을 순서적으로 설계하겠다.
model.add(Dense(1, input_dim = 1, activation ='linear'))    # 입력값(X) / 예측값(Y’) /  Y’ = wX
model.summary()                                          # 모델 구성 보여줌
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 3. 학습 과정 설정
# 학습 방법 : sgd(stocastic gradient descent) / 학습률 : 0.01 / Cost function : mse
# 목표 : 오차를 최소하하기 위해 w, b를 학습
model.compile(optimizer = optimizers.SGD(lr = 0.01), loss='mse')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
# 4. 학습(학습 데이터로 모델 학습 / 테스트 데이터로 모델 검증[모델 평가])
model.fit(x, y, epochs = 200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 457ms/step - loss: 2.1126
# Epoch 2/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6717
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3232
# Epoch 4/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0477
# Epoch 5/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8299
# Epoch 6/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6578
# Epoch 7/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5217
# Epoch 8/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4141
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3291
# Epoch 10/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2619
# Epoch 11/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2087
# Epoch 12/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1667
# ...

# %%
# 5. 예측
print(model.predict([10]))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# [[9.479125]]
